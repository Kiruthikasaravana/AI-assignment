# %% [markdown]
# # **INSTALLATION OF LIBRARIES**

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # **IMPORT LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **UPLOAD THE DATASET**

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-57bb97da-5363-465b-94af-1ce4b864164b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57bb97da-5363-465b-94af-1ce4b864164b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset=pd.read_csv('House Price India.csv')

# %%
dataset.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
dataset.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %% [markdown]
# # **UNIVARIATE ANALYSIS, BI-VARIATE AND MULTIVARIATE ANALYSIS**

# %%
sns.histplot(dataset["living area"])
# Out:
# <Axes: xlabel='living area', ylabel='Count'>

# %%
sns.countplot(x=dataset['Lattitude'])
# Out:
# <Axes: xlabel='Lattitude', ylabel='count'>

# %%
sns.countplot(x=dataset['Number of schools nearby'])
# Out:
# <Axes: xlabel='Number of schools nearby', ylabel='count'>

# %%
sns.boxplot(x=dataset['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bathrooms'>

# %%
sns.boxplot(x=dataset['Postal Code'],y=dataset['lot area'])
# Out:
# <Axes: xlabel='Postal Code', ylabel='lot area'>

# %%
sns.stripplot(x=dataset['Renovation Year'],y=dataset['Date'])
# Out:
# <Axes: xlabel='Renovation Year', ylabel='Date'>

# %%
sns.displot(dataset['Longitude'],color='darkorange')

# %%
sns.stripplot(x=dataset['Price'],y=dataset['Date'])
# Out:
# <Axes: xlabel='Price', ylabel='Date'>

# %%
sns.swarmplot(x=dataset['lot area'],y=dataset['Price'])
# Out:
# <Axes: xlabel='lot area', ylabel='Price'>

# %%
sns.barplot(x='living area',y='number of views',data=dataset,color='blue')
# Out:
# <Axes: xlabel='living area', ylabel='number of views'>

# %%
sns.scatterplot(dataset['living area'])
# Out:
# <Axes: ylabel='living area'>

# %%
sns.lineplot(x=dataset['Date'],y=dataset['id'])
# Out:
# <Axes: xlabel='Date', ylabel='id'>

# %%
sns.lineplot(dataset['number of views'])
# Out:
# <Axes: ylabel='number of views'>

# %%
sns.regplot(x=dataset['number of floors'],y=dataset['lot_area_renov'],color='orange')
# Out:
# <Axes: xlabel='number of floors', ylabel='lot_area_renov'>

# %%
sns.pointplot(x=dataset['Area of the basement'],y=dataset['lot area'])
# Out:
# <Axes: xlabel='Area of the basement', ylabel='lot area'>

# %%
sns.violinplot(x=dataset['Longitude'],y=dataset['Date'])
# Out:
# <Axes: xlabel='Longitude', ylabel='Date'>

# %%
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Perform descriptive statistics on the dataset.**

# %%
dataset['Price'].mean()
# Out:
# 538932.2183310534

# %%
dataset['number of bathrooms'].mean()
# Out:
# 2.1295827633378934

# %%
dataset.Lattitude.value_counts().max()
# Out:
# 13

# %%
dataset.Lattitude.value_counts().min()
# Out:
# 1

# %%
dataset['Lattitude']
# Out:
# 0        52.8645
# 1        52.8878
# 2        52.8852
# 3        52.9532
# 4        52.9047
#           ...
# 14615    52.6191
# 14616    52.5075
# 14617    52.7289
# 14618    52.7157
# 14619    52.5338
# Name: Lattitude, Length: 14620, dtype: float64

# %%
dataset['number of bedrooms']
# Out:
# 0        5
# 1        4
# 2        5
# 3        4
# 4        3
#         ..
# 14615    2
# 14616    3
# 14617    2
# 14618    4
# 14619    3
# Name: number of bedrooms, Length: 14620, dtype: int64

# %%
dataset.Lattitude.value_counts().mode()
# Out:
# 0    1
# Name: Lattitude, dtype: int64

# %%
dataset['grade of the house'].value_counts().to_frame().T
# Out:
#                       7     8     9     6    10   11   5   12  4   13
# grade of the house  6011  4137  1828  1324  804  280  154  55  17  10

# %%
dataset['waterfront present'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # **Handle the Missing values.**

# %%
dataset.isnull()
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0      False  False               False                False        False
# 1      False  False               False                False        False
# 2      False  False               False                False        False
# 3      False  False               False                False        False
# 4      False  False               False                False        False
# ...      ...    ...                 ...                  ...          ...
# 14615  False  False               False                False        False
# 14616  False  False               False                False        False
# 14617  False  False               False                False        False
# 14618  False  False               False                False        False
# 14619  False  False               False                False        False
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
dataset.notnull()
# Out:
#          id  Date  number of bedrooms  number of bathrooms  living area  \
# 0      True  True                True                 True         True
# 1      True  True                True                 True         True
# 2      True  True                True                 True         True
# 3      True  True                True                 True         True
# 4      True  True                True                 True         True
# ...     ...   ...                 ...                  ...          ...
# 14615  True  True                True                 True         True
# 14616  True  True                True                 True         True
# 14617  True  True                True                 True         True
# 14618  True  True                True                 True         True
# 14619  True  True                True                 True         True
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
dataset.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
dataset.fillna(100)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
dataset.fillna(0)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
dataset.iloc[45]
# Out:
# id                                       6.762823e+09
# Date                                     4.249100e+04
# number of bedrooms                       4.000000e+00
# number of bathrooms                      2.500000e+00
# living area                              3.630000e+03
# lot area                                 4.288400e+04
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       9.000000e+00
# Area of the house(excluding basement)    2.300000e+03
# Area of the basement                     1.330000e+03
# Built Year                               1.979000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220230e+05
# Lattitude                                5.249170e+01
# ...

# %%
dataset['Distance from the airport'].fillna(45,inplace=True)

# %%
dataset['Distance from the airport']
# Out:
# 0        58
# 1        51
# 2        53
# 3        76
# 4        51
#          ..
# 14615    76
# 14616    59
# 14617    64
# 14618    54
# 14619    55
# Name: Distance from the airport, Length: 14620, dtype: int64

# %%
dataset['Distance from the airport'].replace({51:40},inplace=True)

# %%
dataset['Distance from the airport']
# Out:
# 0        58
# 1        40
# 2        53
# 3        76
# 4        40
#          ..
# 14615    76
# 14616    59
# 14617    64
# 14618    54
# 14619    55
# Name: Distance from the airport, Length: 14620, dtype: int64

# %%
dataset['Date'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14615    False
# 14616    False
# 14617    False
# 14618    False
# 14619    False
# Name: Date, Length: 14620, dtype: bool

# %%
dataset['id'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14615    False
# 14616    False
# 14617    False
# 14618    False
# 14619    False
# Name: id, Length: 14620, dtype: bool

# %%
dataset.groupby(by='lot area').size()
# Out:
# lot area
# 520        1
# 635        1
# 638        1
# 676        1
# 681        1
#           ..
# 641203     1
# 843309     1
# 982278     1
# 982998     1
# 1074218    1
# Length: 7451, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...
